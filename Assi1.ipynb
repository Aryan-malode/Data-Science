# %% [markdown]
# <a href="https://colab.research.google.com/github/Aryan-malode/Data-Science/blob/main/Assi1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('cricket.csv')
df
# Out:
#    sr.no           name  matches  runs  catches  wickets  stumpings
# 0      1    Anil Dalpat      122  6755       56       12          0
# 1      2   Rohan Kanhay      144  1256       76      178          0
# 2      3  Avdhoot Dighe      265  8954      120        0          0
# 3      4       Bahubali       10   756        6       11          3
# 4      5      Leeladhar      234  2866      105      376          0
# 5      6      Pradyumna      177  5877       47      122          0
# 6      7     Dinesh Roy      211  8537      112       16          0
# 7      8     Parmeshwar      245  9466       53        0          0
# 8      9    Ali Durrani       55  2756       12       26          0
# 9     10   Litesh Singh       89  1099       46       49          0

# %%
df.loc[:,['name','runs']]
# Out:
#             name  runs
# 0    Anil Dalpat  6755
# 1   Rohan Kanhay  1256
# 2  Avdhoot Dighe  8954
# 3       Bahubali   756
# 4      Leeladhar  2866
# 5      Pradyumna  5877
# 6     Dinesh Roy  8537
# 7     Parmeshwar  9466
# 8    Ali Durrani  2756
# 9   Litesh Singh  1099

# %%
s = df.loc[:,'wickets']
s.sum()
# Out:
# 790

# %%
c = df.loc[:,'catches']
c.mean()
# Out:
# 63.3

# %%
w = df[df['stumpings'] > 0]
w
# Out:
#    sr.no      name  matches  runs  catches  wickets  stumpings
# 3      4  Bahubali       10   756        6       11          3

# %%
bowl = df[df['wickets'] > 0]
highest = bowl.loc[bowl['matches'].idxmax(), 'name']
highest
# Out:
# 'Leeladhar'

# %%
avg= bowl.mean()
avg
# Out:
# <ipython-input-37-a66b8bd8e63a>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   avg= bowl.mean()
# sr.no           5.500
# matches       130.250
# runs         3737.750
# catches        57.500
# wickets        98.750
# stumpings       0.375
# dtype: float64

# %%
avg=bowl.mean(1)
avg
# Out:
# <ipython-input-41-1da676753b31>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   avg=bowl.mean(1)
# 0    1157.666667
# 1     276.000000
# 3     131.666667
# 4     597.666667
# 5    1038.166667
# 6    1480.500000
# 8     476.333333
# 9     215.500000
# dtype: float64

# %%
avg.min()
df.iloc[3:4,:]
# Out:
# 131.66666666666666

# %%
# Out:
#    sr.no      name  matches  runs  catches  wickets  stumpings
# 3      4  Bahubali       10   756        6       11          3

# %%
df['ratio']= df['catches'] / df['matches']
df
# Out:
#    sr.no           name  matches  runs  catches  wickets  stumpings     ratio
# 0      1    Anil Dalpat      122  6755       56       12          0  0.459016
# 1      2   Rohan Kanhay      144  1256       76      178          0  0.527778
# 2      3  Avdhoot Dighe      265  8954      120        0          0  0.452830
# 3      4       Bahubali       10   756        6       11          3  0.600000
# 4      5      Leeladhar      234  2866      105      376          0  0.448718
# 5      6      Pradyumna      177  5877       47      122          0  0.265537
# 6      7     Dinesh Roy      211  8537      112       16          0  0.530806
# 7      8     Parmeshwar      245  9466       53        0          0  0.216327
# 8      9    Ali Durrani       55  2756       12       26          0  0.218182
# 9     10   Litesh Singh       89  1099       46       49          0  0.516854

# %%
r= df[df['ratio'] > 0.5]
r
# Out:
#    sr.no          name  matches  runs  catches  wickets  stumpings     ratio
# 1      2  Rohan Kanhay      144  1256       76      178          0  0.527778
# 3      4      Bahubali       10   756        6       11          3  0.600000
# 6      7    Dinesh Roy      211  8537      112       16          0  0.530806
# 9     10  Litesh Singh       89  1099       46       49          0  0.516854

# %%
import matplotlib.pyplot as plt
plt.bar(df['name'], df['runs'])
plt.xlabel('Player Name')
plt.ylabel('Runs')
plt.show()

# %%
s= df.sort_values(by='runs', ascending=True)
s
# Out:
#    sr.no           name  matches  runs  catches  wickets  stumpings     ratio
# 3      4       Bahubali       10   756        6       11          3  0.600000
# 9     10   Litesh Singh       89  1099       46       49          0  0.516854
# 1      2   Rohan Kanhay      144  1256       76      178          0  0.527778
# 8      9    Ali Durrani       55  2756       12       26          0  0.218182
# 4      5      Leeladhar      234  2866      105      376          0  0.448718
# 5      6      Pradyumna      177  5877       47      122          0  0.265537
# 0      1    Anil Dalpat      122  6755       56       12          0  0.459016
# 6      7     Dinesh Roy      211  8537      112       16          0  0.530806
# 2      3  Avdhoot Dighe      265  8954      120        0          0  0.452830
# 7      8     Parmeshwar      245  9466       53        0          0  0.216327

# %%
p =df[df['wickets'] > df['matches']]['name']
p
# Out:
# 1    Rohan Kanhay
# 3        Bahubali
# 4       Leeladhar
# Name: name, dtype: object
